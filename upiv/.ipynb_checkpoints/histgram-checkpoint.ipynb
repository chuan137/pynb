# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import numpy as np
import cv2

# %%
img = cv2.imread('p88.bmp')

imgshape = (100,100,3)
simg = np.zeros(imgshape,dtype='uint8')
pimg = np.zeros(imgshape,dtype='uint8')

for r in range(imgshape[0]):
    for c in range(imgshape[1]):
        simg[r,c] = img[100+r,600+c]

# histogram cuts
lb = 27.5 
hb = lb+2
#hb = 50.5

# clipping histogram
case = 1

if case == 1:
    for r in range(imgshape[0]):
        for c in range(imgshape[1]):
            if simg[r,c,0] < lb:
                pimg[r,c] = [0,0,0]
            elif simg[r,c,0] < hb:
                pimg[r,c] = simg[r,c]
            else:
                pimg[r,c] = [255,255,255]
                #pimg[r,c] = [0,0,0]

if case == 2:
    for r in range(imgshape[0]):
        for c in range(imgshape[1]):
            if simg[r,c,0] < lb:
                pimg[r,c] = [0,0,0]
            elif simg[r,c,0] < hb:
                pimg[r,c] = simg[r,c] + (255 - hb)
            else:
                #pimg[r,c] = [255,255,255]
                pimg[r,c] = [0,0,0]
                
cv2.imwrite('sample.bmp', simg)
cv2.imwrite('processed.bmp', pimg)

plt.figure()
fig, axes = plt.subplots(2,2, figsize=(12,12))

axes[0,0].imshow(simg)
axes[0,1].imshow(pimg)

s = axes[1,1].hist(simg.flatten(),bins=256)
axes[1,1].set_xlim([20,60])

# dilation
kernel = np.ones((3,3),np.uint8)
dilation = cv2.dilate(pimg,kernel,iterations = 4)
axes[1,0].imshow(dilation)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-c87a0564a192> in <module>()
# ----> 1 img = cv2.imread('p88.bmp')
#       2
#       3 imgshape = (100,100,3)
#       4 simg = np.zeros(imgshape,dtype='uint8')
#       5 pimg = np.zeros(imgshape,dtype='uint8')
#
# NameError: name 'cv2' is not defined

# %%
gbs = 1

blur = cv2.GaussianBlur(pimg,(gbs,gbs),0)
edges = cv2.Canny(blur, 30, 55)
circles = cv2.HoughCircles(blur[:,:,0],cv2.cv.CV_HOUGH_GRADIENT,1,10,param1=5,param2=18,minRadius=0,maxRadius=0)
print circles

if circles is not None:
    for i in circles[0,:]:
        if i[2] < 10.5:
            # draw the outer circle
            cv2.circle(blur,(i[0],i[1]),i[2],(0,255,0),2)
            # draw the center of the circle
            cv2.circle(blur,(i[0],i[1]),2,(0,0,255),3)

plt.figure()
fig, axes = plt.subplots(1,3, figsize=(24,8))
axes[0].imshow(pimg)
axes[1].imshow(blur)
axes[2].imshow(edges, cmap='gray')
# Out:
# [[[ 68.5         53.5         16.56804085]
#   [ 67.5         36.5         11.33578396]
#   [ 48.5         65.5         12.34908867]
#   [ 53.5         84.5          7.51664829]
#   [ 67.5         81.5          6.51920223]
#   [ 57.5         36.5         12.34908867]
#   [ 41.5         36.5          5.52268028]
#   [ 68.5         19.5         23.71708298]
#   [ 57.5         70.5         10.12422848]
#   [ 36.5         67.5          8.74642754]
#   [ 54.5         23.5          8.63133812]
#   [ 51.5         55.5         10.97724915]
#   [ 30.5         47.5          7.51664829]
#   [ 41.5         46.5         10.97724915]
#   [ 41.5         26.5          6.04152298]
#   [ 25.5         56.5          6.51920223]
#   [ 29.5         92.5          6.51920223]
#   [ 82.5         61.5          6.04152298]
#   [ 57.5         13.5         12.58967876]
#   [ 79.5         45.5          5.52268028]
#   [  9.5         68.5         33.77128983]
#   [ 85.5         76.5         13.65649986]
#   [ 40.5          9.5         12.34908867]
#   [ 41.5         90.5          8.74642754]
#   [ 68.5          6.5         21.78302002]
#   [ 31.5         28.5         14.57738018]
#   [ 71.5         65.5         13.20984459]
#   [ 85.5          2.5         33.14362717]
#   [ 93.5         93.5         29.3001709 ]
#   [ 26.5         69.5         15.50806236]
#   [ 77.5         94.5         21.82888031]
#   [ 77.5         14.5         31.66228104]
#   [ 80.5         29.5         11.33578396]
#   [ 95.5         53.5         17.84656906]]]
